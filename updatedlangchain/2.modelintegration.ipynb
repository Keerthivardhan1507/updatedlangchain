# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] =os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] =os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] =os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
from langchain_groq import ChatGroq
llm = ChatGroq(
    model = "llama-3.3-70b-versatile")
llm
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001FA8AD3C550>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001FA8AD3CF50>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
##invoke the model

response= llm.invoke("Hello How are you")
response
# Out:
# AIMessage(content="Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 39, 'total_tokens': 96, 'completion_time': 0.125293, 'completion_tokens_details': None, 'prompt_time': 0.001732015, 'prompt_tokens_details': None, 'queue_time': 0.049310334, 'total_time': 0.127025015}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ea07d-2661-7e02-84aa-07e880b422ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 57, 'total_tokens': 96})

# %%
response.content
# Out:
# "Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?"

# %%
##Google Gemini Model
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Who has the  most number 1 ODI Batsman across the world")
response
# Out:
# AIMessage(content='The player with the **most number of individual ODI Batsman of the Year awards** across the world is **Sachin Tendulkar**.\n\nHe has won this prestigious award **three times**:\n\n*   **1998**\n*   **2001**\n*   **2004**\n\nIt\'s important to clarify that this refers to the individual award, not necessarily the number of times a player has been ranked number 1 in the ICC ODI Player Rankings at any given point. The "ODI Batsman of the Year" award is a recognition given by the International Cricket Council (ICC) based on a player\'s performance over a specific year.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ea081-9e55-7ca2-850d-d412218dfdc5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 138, 'total_tokens': 153, 'input_token_details': {'cache_read': 0}})

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
